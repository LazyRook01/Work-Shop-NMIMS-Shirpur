# %%
import numpy as np
import pandas as pd
import sklearn

# %%
churn_df = pd.read_csv("telecom_churn_clean.csv", index_col=0)

# %% [markdown]
# # Exercise 2

# %% [markdown]
# 1. Import `KNeighborsClassifier` from `sklearn.neighbors`
# 2. Instantiate a KNeighborsClassifier called knn with 6 neighbors
# 3. Fit the classifier to the data using `.fit()` method

# %%
from sklearn.neighbors import KNeighborsClassifier
X = churn_df[["total_day_charge", "total_eve_charge"]].values
y  = churn_df["churn"].values
print(X.shape,  y.shape)
# Out:
# (3333, 2) (3333,)

# %%
knn = KNeighborsClassifier(n_neighbors=6)
knn.fit(X,y)
# Out:
# KNeighborsClassifier(n_neighbors=6)

# %% [markdown]
# # Exercise 3

# %% [markdown]
# 1. Now you have fit a KNN classifier, you can use it to predict the label of new data points. All available data was used for training, however, fortunately, there are new observations available. These have been preloaded for you as X_new.
#
# 2. The model knn, which you created and fit the data in the last exercise, has been preloaded for you. You will use your classifier to predict the labels of a set of new data points:
#
# ```
# X_new = np.array([[30.0, 17.5],
#                   [107.0, 24.1],
#                   [213.0, 10.9]])
# ```

# %%
X_new = np.array([[30.0, 17.5],
                  [107.0, 24.1],
                  [213.0, 10.9]])
print(X_new.shape)
# Out:
# (3, 2)

# %%
# Predict the labels for the X_new
y_pred = knn.predict(X_new)

# Print the predictions
print("Predictions: {}".format(y_pred))
# Out:
# Predictions: [0 1 1]
